# %% [markdown]
# # Creating Analytic Dataset
#
# **STEPS**:
# 1. Merging neighborhood-level house price and house value index dataset with neighborhood-level school quality dataset.
# 2. *Merging with demographics dataset*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sales = pd.read_csv("./data/cleaned_neighbor_sales.csv")
df_school = pd.read_csv("./data/schools_neighborhoods.csv")

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Neighborhood        3028 non-null   object
#  1   Year                3028 non-null   int64
#  2   Number Of Sales     3028 non-null   int64
#  3   Average Sale Price  3028 non-null   float64
#  4   Median Sale Price   3028 non-null   float64
#  5   Lowest Sale Price   3028 non-null   int64
#  6   Highest Sale Price  3028 non-null   int64
#  7   Match               2429 non-null   object
#  8   Borough             2425 non-null   object
#  9   HVI                 2423 non-null   float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 236.7+ KB

# %%
df_school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2184 entries, 0 to 2183
# Data columns (total 55 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   fiscal_year                        2184 non-null   int64
#  1   system_code                        2184 non-null   object
#  2   location_code                      2184 non-null   object
#  3   location_name                      2184 non-null   object
#  4   BEDS                               2184 non-null   int64
#  5   Managed_by_name                    2184 non-null   object
#  6   location_type_description          2184 non-null   object
#  7   Location_Category_Description      2184 non-null   object
#  8   Grades_text                        2101 non-null   object
#  9   Grades_final_text                  2098 non-null   object
#  10  open_date                          2184 non-null   object
# ...

# %%
df_school.sample(5)
# Out:
#       fiscal_year system_code location_code  \
# 1153         2020      25Q024          Q024
# 23           2020      14K023          K023
# 1007         2020      84M433          M433
# 1090         2020      02M580          M580
# 2088         2020      08X540          X540
#
#                                        location_name          BEDS  \
# 1153                         P.S. 024 Andrew Jackson  342500010024
# 23                        P.S. 023 Carter G. Woodson  331400010023
# 1007  Renaissance Charter High School for Innovation  310400860968
# 1090        Richard R. Green High School of Teaching  310200011580
# 2088      School for Community Research and Learning  320800011540
#
#      Managed_by_name location_type_description Location_Category_Description  \
# 1153             DOE          General Academic                    Elementary
# 23               DOE          General Academic                    Elementary
# ...
